# %% [markdown]
# # ARIMA Time Series Forecasting Preprocessing and EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## EDA and Preprocessing

# %%
# Load the data
data=pd.read_csv('New motor vehicle sales data.csv')

# Display the shape of the data
data.shape
# Out:
# (160918, 18)

# %%
# Display the first few rows of the data
data.head()
# Out:
#   REF_DATE     GEO           DGUID               Vehicle type  \
# 0  1946-10  Canada  2016A000011124  Total, new motor vehicles
# 1  1946-11  Canada  2016A000011124  Total, new motor vehicles
# 2  1946-12  Canada  2016A000011124  Total, new motor vehicles
# 3  1947-01  Canada  2016A000011124  Total, new motor vehicles
# 4  1947-02  Canada  2016A000011124  Total, new motor vehicles
#
#            Origin of manufacture  Sales Seasonal adjustment    UOM  UOM_ID  \
# 0  Total, country of manufacture  Units          Unadjusted  Units     300
# 1  Total, country of manufacture  Units          Unadjusted  Units     300
# 2  Total, country of manufacture  Units          Unadjusted  Units     300
# 3  Total, country of manufacture  Units          Unadjusted  Units     300
# 4  Total, country of manufacture  Units          Unadjusted  Units     300
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE    VALUE STATUS  SYMBOL  \
# 0         units          0  v42169911  1.1.1.1.1  11462.0    NaN     NaN
# 1         units          0  v42169911  1.1.1.1.1  13497.0    NaN     NaN
# 2         units          0  v42169911  1.1.1.1.1  12689.0    NaN     NaN
# 3         units          0  v42169911  1.1.1.1.1  13977.0    NaN     NaN
# 4         units          0  v42169911  1.1.1.1.1  15806.0    NaN     NaN
#
#   TERMINATED  DECIMALS
# 0        NaN         0
# 1        NaN         0
# 2        NaN         0
# 3        NaN         0
# 4        NaN         0

# %% [markdown]
# ### Checked missing value
#
# since no missing value in the main columns we need "REF_DATE" and "Value", no need to drop any missing value

# %%
# check for missing values
data.isnull().sum()
# Out:
# REF_DATE                      0
# GEO                           0
# DGUID                     14362
# Vehicle type                  0
# Origin of manufacture         0
# Sales                         0
# Seasonal adjustment           0
# UOM                           0
# UOM_ID                        0
# SCALAR_FACTOR                 0
# SCALAR_ID                     0
# VECTOR                        0
# COORDINATE                    0
# VALUE                     18441
# STATUS                   142477
# SYMBOL                   160918
# TERMINATED               155134
# DECIMALS                      0
# dtype: int64

# %% [markdown]
# ### Check duplicates

# %%
# Check for duplicates
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Deal with aggregated data
#
# We found that in the dataset, there is aggregated
# 1. GEO: national data and provincial data.
# 2. Vehicle type: Passenger, Truck, and Total New
# 3. Origin of manufacture: "Japen", "North America", "Other Countries", "Total, country of manufacture", "Total, overseas"

# %%
# Display the unique value within each columns
data.nunique()
# Out:
# REF_DATE                   929
# GEO                         11
# DGUID                       10
# Vehicle type                 3
# Origin of manufacture        5
# Sales                        2
# Seasonal adjustment          2
# UOM                          2
# UOM_ID                       2
# SCALAR_FACTOR                2
# SCALAR_ID                    2
# VECTOR                     257
# COORDINATE                 257
# VALUE                    63879
# STATUS                       1
# SYMBOL                       0
# TERMINATED                   1
# DECIMALS                     1
# dtype: int64

# %% [markdown]
# #### 1.Deal with aggregated GEO

# %%
# Display the  unique values in the 'GEO' column
data['GEO'].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia and the Territories'],
#       dtype=object)

# %%
# Split the data with 'GEO="Canada"'
data_canada=data[data['GEO']=='Canada']

# Display the shape of the data
data_canada.head()
# Out:
#   REF_DATE     GEO           DGUID               Vehicle type  \
# 0  1946-10  Canada  2016A000011124  Total, new motor vehicles
# 1  1946-11  Canada  2016A000011124  Total, new motor vehicles
# 2  1946-12  Canada  2016A000011124  Total, new motor vehicles
# 3  1947-01  Canada  2016A000011124  Total, new motor vehicles
# 4  1947-02  Canada  2016A000011124  Total, new motor vehicles
#
#            Origin of manufacture  Sales Seasonal adjustment    UOM  UOM_ID  \
# 0  Total, country of manufacture  Units          Unadjusted  Units     300
# 1  Total, country of manufacture  Units          Unadjusted  Units     300
# 2  Total, country of manufacture  Units          Unadjusted  Units     300
# 3  Total, country of manufacture  Units          Unadjusted  Units     300
# 4  Total, country of manufacture  Units          Unadjusted  Units     300
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE    VALUE STATUS  SYMBOL  \
# 0         units          0  v42169911  1.1.1.1.1  11462.0    NaN     NaN
# 1         units          0  v42169911  1.1.1.1.1  13497.0    NaN     NaN
# 2         units          0  v42169911  1.1.1.1.1  12689.0    NaN     NaN
# 3         units          0  v42169911  1.1.1.1.1  13977.0    NaN     NaN
# 4         units          0  v42169911  1.1.1.1.1  15806.0    NaN     NaN
#
#   TERMINATED  DECIMALS
# 0        NaN         0
# 1        NaN         0
# 2        NaN         0
# 3        NaN         0
# 4        NaN         0

# %%
# Display the shape of the data
data_canada.shape
# Out:
# (19650, 18)

# %%
#Split for provincial data 'GEO!="Canada"
data_provincial=data[data['GEO']!='Canada']

#Display the unique values in the 'GEO' column to confirm that the rows with 'GEO="Canada" have been removed
# data['GEO'].unique()

#Display the shape of the data
data_provincial.shape
# Out:
# (141268, 18)

# %%
# Display the first few rows of the data
data_provincial.head()
# Out:
#       REF_DATE                        GEO        DGUID  \
# 19650  1968-01  Newfoundland and Labrador  2016A000210
# 19651  1968-02  Newfoundland and Labrador  2016A000210
# 19652  1968-03  Newfoundland and Labrador  2016A000210
# 19653  1968-04  Newfoundland and Labrador  2016A000210
# 19654  1968-05  Newfoundland and Labrador  2016A000210
#
#                     Vehicle type          Origin of manufacture  Sales  \
# 19650  Total, new motor vehicles  Total, country of manufacture  Units
# 19651  Total, new motor vehicles  Total, country of manufacture  Units
# 19652  Total, new motor vehicles  Total, country of manufacture  Units
# 19653  Total, new motor vehicles  Total, country of manufacture  Units
# 19654  Total, new motor vehicles  Total, country of manufacture  Units
#
#       Seasonal adjustment    UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR  \
# 19650          Unadjusted  Units     300         units          0  v42169996
# 19651          Unadjusted  Units     300         units          0  v42169996
# 19652          Unadjusted  Units     300         units          0  v42169996
# 19653          Unadjusted  Units     300         units          0  v42169996
# 19654          Unadjusted  Units     300         units          0  v42169996
#
#       COORDINATE   VALUE STATUS  SYMBOL TERMINATED  DECIMALS
# 19650  2.1.1.1.1   754.0    NaN     NaN        NaN         0
# 19651  2.1.1.1.1   895.0    NaN     NaN        NaN         0
# 19652  2.1.1.1.1  1569.0    NaN     NaN        NaN         0
# 19653  2.1.1.1.1  1390.0    NaN     NaN        NaN         0
# 19654  2.1.1.1.1  1567.0    NaN     NaN        NaN         0

# %% [markdown]
# #### 2.Deal with aggregated Vehicle type

# %%
# Display the  unique values in the 'Vehicle type' column
data_canada['Vehicle type'].unique()
# Out:
# array(['Total, new motor vehicles', 'Passenger cars', 'Trucks'],
#       dtype=object)

# %%
data_canada.shape
# Out:
# (19650, 18)

# %%
# create a new df that only contains 'Passenger cars','Trucks'
data_canada_vehicleType=data_canada[data_canada['Vehicle type'].isin(['Passenger cars','Trucks'])]
data_canada_vehicleType.shape
# Out:
# (15994, 18)

# %%
# Display the unique values in the 'Vehicle type' column
data_provincial['Vehicle type'].unique()
# Out:
# array(['Total, new motor vehicles', 'Passenger cars', 'Trucks'],
#       dtype=object)

# %%
data_provincial.shape
# Out:
# (141268, 18)

# %%
# create a new df that only contains 'Passenger cars','Trucks'
data_provincial_vehicleType=data_provincial[data_provincial['Vehicle type'].isin(['Passenger cars','Trucks'])]
data_provincial_vehicleType.shape
# Out:
# (109808, 18)

# %% [markdown]
# #### 3.Deal with aggregated Country of Origin

# %%
# create a new df that only contains Japan, North America, Other Countries
data_canada_vehicleType_country=data_canada_vehicleType[data_canada_vehicleType['Origin of manufacture'].isin(['Japan','North America','Other countries'])]
data_canada_vehicleType_country.shape
# Out:
# (6582, 18)

# %%
# create a new df that only contains Japan, North America, Other Countries
data_provincial_vehicleType_country=data_provincial_vehicleType[data_provincial_vehicleType['Origin of manufacture'].isin(['Japan','North America','Other countries'])]
data_provincial_vehicleType_country.shape
# Out:
# (53704, 18)

# %% [markdown]
# ### Plot

# %%
# Plot the "REF_DATE" and "Value" pair for each "GEO"

# Adjust figure size
plt.figure(figsize=(20, 10))

# Plot the lineplot
sns.lineplot(data=data_provincial_vehicleType_country, x='REF_DATE', y='VALUE', hue='GEO')

# Add more space for y-axis labels
plt.ylim(bottom=0)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Sales vs Year for each Provinces')

# Show the plot
plt.show()

# %%
# Adjust figure size
plt.figure(figsize=(25, 6))

# Format the date column to display only the last 2 digits of the year
data_canada['REF_DATE'] = pd.to_datetime(data_canada['REF_DATE']).dt.strftime('%y')

# Plot the lineplot
sns.lineplot(data=data_canada_vehicleType_country, x='REF_DATE', y='VALUE')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Value vs Year for Canada')
plt.show()
# Out:
# /var/folders/tr/psvn_y8x0w34ssccnb237zq00000gn/T/ipykernel_18081/3041316588.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_canada['REF_DATE'] = pd.to_datetime(data_canada['REF_DATE']).dt.strftime('%y')

# %% [markdown]
# # Export processed file
